# %%
import time
from datetime import datetime
t = datetime.now().strftime('%H:%M:%S')
print(f'{t} Sleeping 30s')
time.sleep(30)
t = datetime.now().strftime('%H:%M:%S')
print(f'{t} Slept 30s')
123 + 456
